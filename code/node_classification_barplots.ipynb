# %%
import matplotlib.pyplot as plt
import numpy as np

purple_ = '#BF55EC'
yellow_ = '#F7CA18'

labels = ['DeepWalk', 'FairWalk', 'CrossWalk']
accuracy_means_our = [79.24439461883408, 74.33632286995517, 30.132286995515695]
accuracy_min_max = np.array([[72.19730941704036, 84.30493273542601], [66.81614349775785, 79.82062780269058], [22.869955156950674, 36.771300448430495]])
acc_err_our = np.array([(mean-min, max-mean) for mean, (min, max) in zip(accuracy_means_our, accuracy_min_max.tolist())]).T

disparity_means_our = [205.2821218107538, 119.0225343476247, 17.542225623210268]
disparity_min_max = np.array([[47.149340227244736, 531.0282388874407], [0.1505356222488088, 415.8686224489794], [0.00014172335600909044, 84.62145181619547]])
disp_err_our = np.array([(mean-min, max-mean) for mean, (min, max) in zip(disparity_means_our, disparity_min_max.tolist())]).T

accuracy_means_auth = [80, 79, 78]
disparity_means_auth = [178, 75, 60]

x = np.array([2, 5.5, 9, 12.5]) # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width*1.5 -0.1, accuracy_means_auth, width, label='Accuracy Author\'s', color=purple_)
bars2 = ax.bar(x - width/2 -0.1, disparity_means_auth, width, label='Disparity Author\'s', color=yellow_)
bars3 = ax.bar(x + width/2 +0.1, accuracy_means_our, width, label='Total Accuracy Reproduction', color="blue", yerr=acc_err_our)
bars4 = ax.bar(x + width*1.5 +0.1, disparity_means_our, width, label='Disparity Reproduction', color="orange", yerr=disp_err_our)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('%')
ax.set_title('Node classification on \nRice-Facebook Dataset')
ax.set_xticks(x, labels)
ax.legend()

# ax.bar_label(bars1, padding=3)
# ax.bar_label(bars2, padding=3)
#
# ax.bar_label(bars3, padding=3)
# ax.bar_label(bars4, padding=3)

ax.set_ylim(top=100)
fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 23
#      20 width = 0.35  # the width of the bars
#      22 fig, ax = plt.subplots()
# ---> 23 bars1 = ax.bar(x - width*1.5 -0.1, accuracy_means_auth, width, label='Accuracy Author\'s', color=purple_)
#      24 bars2 = ax.bar(x - width/2 -0.1, disparity_means_auth, width, label='Disparity Author\'s', color=yellow_)
#      25 bars3 = ax.bar(x + width/2 +0.1, accuracy_means_our, width, label='Total Accuracy Reproduction', color="blue", yerr=acc_err_our)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/fact-ai/lib/python3.10/site-packages/matplotlib/__init__.py:1433, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1430 @functools.wraps(func)
#    1431 def inner(ax, *args, data=None, **kwargs):
#    1432     if data is None:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

purple_ = '#BF55EC'
yellow_ = '#F7CA18'

labels = ['DeepWalk', 'FairWalk', 'CrossWalk']
accuracy_means_our = [86.5320910973085, 86.13768115942028, 72.26497933884299]
accuracy_min_max = np.array([[85.56935817805383, 87.32919254658385],[84.472049689441, 88.01242236024845],[71.30681818181819, 73.4245867768595]])
acc_err_our = np.array([(mean-min, max-mean) for mean, (min, max) in zip(accuracy_means_our, accuracy_min_max.tolist())]).T

disparity_means_our = [368.533378600834, 250.00255579255358, 4.854143275091014]
disparity_min_max = np.array([[154.36717516193826, 641.3699310244459], [107.12364877234057, 461.2267262645264], [0.5987003363942259, 33.18844965572752]])
disp_err_our = np.array([(mean-min, max-mean) for mean, (min, max) in zip(disparity_means_our, disparity_min_max.tolist())]).T

accuracy_means_auth = [69.45, 69.17, 68.02]
disparity_means_auth = [83.65, 63.82, 42.79]

x = np.array([7, 14, 21]) # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width*1.5-0.1, accuracy_means_auth, width, label='Total Accuracy Author\'s', color=purple_)
bars2 = ax.bar(x - width/2-0.1, disparity_means_auth, width, label='Disparity Author\'s', color=yellow_)
bars3 = ax.bar(x + width/2+0.1, accuracy_means_our, width, label='Total Accuracy Reproduction', color="blue", yerr=acc_err_our)
bars4 = ax.bar(x + width*1.5+0.1, disparity_means_our, width, label='Disparity Reproduction', color="orange", yerr=disp_err_our)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Node classification on \nFacebook-Rice Dataset')
ax.set_xticks(x, labels)
ax.legend()

# ax.bar_label(bars1, padding=3)
# ax.bar_label(bars2, padding=3)
#
# ax.bar_label(bars3, padding=3)
# ax.bar_label(bars4, padding=3)

ax.set_ylim(top=275)
fig.tight_layout()

plt.show()
